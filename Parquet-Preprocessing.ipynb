# %%
import pandas as pd

# %%
columns = ("L3 Emp Crediting Hierarchy"," Concat", "Metric 1", "Metric 2", "Metric 3", "Transaction Type", "Source", "Transaction ID", "PBI Index Date", "Transaction Amount (USD $)", "Delta Date")

# %%
all = pd.read_csv("CALC_ Employee Transactions (1).txt",names=columns)

# %%
pip install pandas pyarrow
# Out:
# ...
#      --------------------------------------- 20.2/20.2 MB 32.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\PC\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pyarrow as pa
import pyarrow.parquet as pq

# %%
all.to_parquet('CALC_ Employee Transactions (1).txt.parquet')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 all.to_parquet('CALC_ Employee Transactions (1).txt.parquet')
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'to_parquet'

# %%
allx = pd.read_parquet('CALC_ Employee Transactions (1).txt.parquet')

# %%
allx.tail()
# Out:
#                                  L3 Emp Crediting Hierarchy   Concat  \
# 62813070  #71953971\t90709986TECH CONSULTANT AP\tfalse\t...      NaN
# 62813071  #71953972\t90709986TECH CONSULTANT AP\tfalse\t...      NaN
# 62813072  #60648140\t90710169AM SI AP\ttrue\tfalse\tfals...      NaN
# 62813073  #60648141\t90710169AM SI AP\ttrue\tfalse\tfals...      NaN
# 62813074  #60648142\t90710169AM SI AP\ttrue\tfalse\tfals...      NaN
#
#           Metric 1  Metric 2  Metric 3  Transaction Type  Source  \
# 62813070       NaN       NaN       NaN               NaN     NaN
# 62813071       NaN       NaN       NaN               NaN     NaN
# 62813072       NaN       NaN       NaN               NaN     NaN
# 62813073       NaN       NaN       NaN               NaN     NaN
# 62813074       NaN       NaN       NaN               NaN     NaN
#
#           Transaction ID  PBI Index Date  Transaction Amount (USD $)  \
# 62813070             NaN             NaN                         NaN
# ...

# %%
allx1 = allx['L3 Emp Crediting Hierarchy'].str.split('\t', expand=True)

# %%
allx1.head()
# Out:
#                            0               1         2         3         4   \
# 0  L3 Emp Crediting Hierarchy          Concat  Metric 1  Metric 2  Metric 3
# 1                       #5173  10014182RVP LA      true     false     false
# 2                       #5174  10014182RVP LA      true     false     false
# 3                       #5175  10014182RVP LA      true     false     false
# 4                       #5176  10014182RVP LA      true     false     false
#
#                  5                      6          7           8   \
# 0  Transaction Type  Source Transaction ID  PBI Index        Date
# 1             SFSAC      150623438C|000001             2022-10-03
# 2             SFSAC      150629288C|000010             2022-10-05
# 3             SFSAC      150629288C|000028             2022-10-05
# 4             SFSAC      150629288C|000057             2022-10-05
#
#                            9           10
# 0  Transaction Amount (USD $)  Delta Date
# ...

# %%
allx2 = allx1.drop(index=0)

# %%
allx2.head()
# Out:
#       0               1     2      3      4      5                  6  7   \
# 1  #5173  10014182RVP LA  true  false  false  SFSAC  150623438C|000001
# 2  #5174  10014182RVP LA  true  false  false  SFSAC  150629288C|000010
# 3  #5175  10014182RVP LA  true  false  false  SFSAC  150629288C|000028
# 4  #5176  10014182RVP LA  true  false  false  SFSAC  150629288C|000057
# 5  #5177  10014182RVP LA  true  false  false  SFSAC  150629288C|000066
#
#            8       9           10
# 1  2022-10-03    -5.4  2022-11-10
# 2  2022-10-05  -20.83  2022-11-10
# 3  2022-10-05  -42.42  2022-11-10
# 4  2022-10-05  -18.21  2022-11-10
# 5  2022-10-05  -36.15  2022-11-10

# %%
columns = ("L3 Emp Crediting Hierarchy","Concat", "Metric 1", "Metric 2", "Metric 3", "Transaction Type", "Source Transaction ID", "PBI Index", "Date", "Transaction Amount (USD $)", "Delta Date")

# %%
allx2.columns= ["L3 Emp Crediting Hierarchy"," Concat", "Metric 1", "Metric 2", "Metric 3", "Transaction Type", "Source Transaction ID", "PBI Index", "Date", "Transaction Amount (USD $)", "Delta Date"]

# %%
allx2.head()
# Out:
#   L3 Emp Crediting Hierarchy          Concat Metric 1 Metric 2 Metric 3  \
# 1                      #5173  10014182RVP LA     true    false    false
# 2                      #5174  10014182RVP LA     true    false    false
# 3                      #5175  10014182RVP LA     true    false    false
# 4                      #5176  10014182RVP LA     true    false    false
# 5                      #5177  10014182RVP LA     true    false    false
#
#   Transaction Type Source Transaction ID PBI Index        Date  \
# 1            SFSAC     150623438C|000001            2022-10-03
# 2            SFSAC     150629288C|000010            2022-10-05
# 3            SFSAC     150629288C|000028            2022-10-05
# 4            SFSAC     150629288C|000057            2022-10-05
# 5            SFSAC     150629288C|000066            2022-10-05
#
#   Transaction Amount (USD $)  Delta Date
# 1                       -5.4  2022-11-10
# 2                     -20.83  2022-11-10
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#      -------------------------------------- 242.1/242.1 kB 3.7 MB/s eta 0:00:00
# ...

# %%
semana1 = pd.read_csv("SIP Employee Transactions 12-10-2022.txt", names=columns)

# %%
semana1.to_parquet('SIP Employee Transactions 12-10-2022.txt.parquet')

# %%
semana1p = pd.read_parquet('SIP Employee Transactions 12-10-2022.txt.parquet')

# %%
semana1p.head()
# Out:
#                           L3 Emp Crediting Hierarchy  Concat  Metric 1  \
# 0  L3 Emp Crediting Hierarchy\tConcat\tMetric 1\t...     NaN       NaN
# 1  #5173\t10014182RVP LA\ttrue\tfalse\tfalse\tSFS...     NaN       NaN
# 2  #5174\t10014182RVP LA\ttrue\tfalse\tfalse\tSFS...     NaN       NaN
# 3  #5175\t10014182RVP LA\ttrue\tfalse\tfalse\tSFS...     NaN       NaN
# 4  #5176\t10014182RVP LA\ttrue\tfalse\tfalse\tSFS...     NaN       NaN
#
#    Metric 2  Metric 3  Transaction Type  Source Transaction ID  \
# 0       NaN       NaN               NaN                    NaN
# 1       NaN       NaN               NaN                    NaN
# 2       NaN       NaN               NaN                    NaN
# 3       NaN       NaN               NaN                    NaN
# 4       NaN       NaN               NaN                    NaN
#
#    PBI Index Date  Transaction Amount (USD $)  Delta Date
# 0             NaN                         NaN         NaN
# ...

# %%
semana1p.tail()
# Out:
#                                  L3 Emp Crediting Hierarchy  Concat  Metric 1  \
# 28195186  #28195063\t90709503SOLUTION CONSULTANT AP\tfal...     NaN       NaN
# 28195187  #28195064\t90709503SOLUTION CONSULTANT AP\tfal...     NaN       NaN
# 28195188  #28195065\t90709503SOLUTION CONSULTANT AP\tfal...     NaN       NaN
# 28195189  #28195066\t90709503SOLUTION CONSULTANT AP\tfal...     NaN       NaN
# 28195190  #28195067\t90709503SOLUTION CONSULTANT AP\tfal...     NaN       NaN
#
#           Metric 2  Metric 3  Transaction Type  Source Transaction ID  \
# 28195186       NaN       NaN               NaN                    NaN
# 28195187       NaN       NaN               NaN                    NaN
# 28195188       NaN       NaN               NaN                    NaN
# 28195189       NaN       NaN               NaN                    NaN
# 28195190       NaN       NaN               NaN                    NaN
#
#           PBI Index Date  Transaction Amount (USD $)  Delta Date
# ...

# %%
semana1pt = semana1p['L3 Emp Crediting Hierarchy'].str.split('\t', expand=True)

# %%
semana1pt.head()
# Out:
#                            0               1         2         3         4   \
# 0  L3 Emp Crediting Hierarchy          Concat  Metric 1  Metric 2  Metric 3
# 1                       #5173  10014182RVP LA      true     false     false
# 2                       #5174  10014182RVP LA      true     false     false
# 3                       #5175  10014182RVP LA      true     false     false
# 4                       #5176  10014182RVP LA      true     false     false
#
#                  5                      6          7           8   \
# 0  Transaction Type  Source Transaction ID  PBI Index        Date
# 1             SFSAC      150623438C|000001             2022-10-03
# 2             SFSAC      150629288C|000010             2022-10-05
# 3             SFSAC      150629288C|000028             2022-10-05
# 4             SFSAC      150629288C|000057             2022-10-05
#
#                            9           10
# 0  Transaction Amount (USD $)  Delta Date
# ...

# %%
semana1pt.tail()
# Out:
#                  0                               1      2      3     4    5   \
# 28195186  #28195063  90709503SOLUTION CONSULTANT AP  false  false  true  SCT
# 28195187  #28195064  90709503SOLUTION CONSULTANT AP  false  false  true  SCT
# 28195188  #28195065  90709503SOLUTION CONSULTANT AP  false  false  true  SCT
# 28195189  #28195066  90709503SOLUTION CONSULTANT AP  false  false  true  SCT
# 28195190  #28195067  90709503SOLUTION CONSULTANT AP  false  false  true  SCT
#
#                          6  7           8        9           10
# 28195186  0059875543|011976     2022-10-30   670.69  2022-11-28
# 28195187  0059875544|011687     2022-10-30   693.39  2022-11-28
# 28195188  0059875544|011704     2022-10-30  1137.17  2022-11-28
# 28195189  0059875544|011717     2022-10-30    59.65  2022-11-28
# 28195190  0059875544|011921     2022-10-30   743.29  2022-11-28

# %%
semana1tx=semana1pt.drop(index=0)

# %%
semana1tx.head()
# Out:
#                 1
# 1  10014182RVP LA
# 2  10014182RVP LA
# 3  10014182RVP LA
# 4  10014182RVP LA
# 5  10014182RVP LA

# %%
semana1tx= semana1tx.drop([0,2,3,4,5,6,7,8,9,10], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 semana1tx= semana1tx.drop([0,2,3,4,5,6,7,8,9,10], axis=1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5240 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df1 = pd.merge(allx2, semana1tx, left_on = ' Concat', right_on = 1, how='left')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 df1 = pd.merge(allx2, semana1tx, left_on = ' Concat', right_on = 1, how='left')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:124, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
#     110     op = _MergeOperation(
#     111         left,
#     112         right,
#    (...)
#     122         validate=validate,
#     123     )
# --> 124     return op.get_result(copy=copy)
#
# ...

# %%
df1.head()
# Out:
#                     0         1 Unnamed: 0      Transaction ID    Source  \
# 0       TransactionID    Source        NaN                 NaN       NaN
# 1  9354016273|700109|  Billings        NaN                 NaN       NaN
# 2  9354016274|700050|  Billings         #2  9354016274|700050|  Billings
# 3  9354016276|700052|  Billings        NaN                 NaN       NaN
# 4  9354016278|700114|  Billings        NaN                 NaN       NaN
#
#           Account Name   BPID List APR Code PBI Transaction Description  \
# 0                  NaN         NaN      NaN                         NaN
# 1                  NaN         NaN      NaN                         NaN
# 2  Precision Peru S.A.  30211512.0      PE1                         SAP
# 3                  NaN         NaN      NaN                         NaN
# 4                  NaN         NaN      NaN                         NaN
#
#                       Type Business Unit  Distributor ID Reference  \
# ...

# %%
df1[1].value_counts()
# Out:
# GPOS                      1106541
# Claims                     473692
# Bookings                   407590
# Billings                   390368
# Contracts                   21347
# Transaction Adjustment       5533
# Name: Source, dtype: int64

# %%
import numpy as np
df1['IGUAL'] = np.where((df1['Concat'] == df1[1]), 'TRUE', np.nan)

# %%
df1.head()
# Out:
#                     0         1 Unnamed: 0      Transaction ID    Source  \
# 0       TransactionID    Source        NaN                 NaN       NaN
# 1  9354016273|700109|  Billings        NaN                 NaN       NaN
# 2  9354016274|700050|  Billings         #2  9354016274|700050|  Billings
# 3  9354016276|700052|  Billings        NaN                 NaN       NaN
# 4  9354016278|700114|  Billings        NaN                 NaN       NaN
#
#           Account Name   BPID List APR Code PBI Transaction Description  \
# 0                  NaN         NaN      NaN                         NaN
# 1                  NaN         NaN      NaN                         NaN
# 2  Precision Peru S.A.  30211512.0      PE1                         SAP
# 3                  NaN         NaN      NaN                         NaN
# 4                  NaN         NaN      NaN                         NaN
#
#                       Type Business Unit  Distributor ID Reference  \
# ...

# %%
df1.tail()
# Out:
#                 0         1 Unnamed: 0 Transaction ID    Source  \
# 3938949  26228919  Bookings        NaN            NaN       NaN
# 3938950  26142191  Bookings        NaN            NaN       NaN
# 3938951  26088581  Bookings   #3938951       26088581  Bookings
# 3938952  26098822  Bookings   #3938952       26098822  Bookings
# 3938953                            NaN            NaN       NaN
#
#                   Account Name   BPID List APR Code  \
# 3938949                    NaN         NaN      NaN
# 3938950                    NaN         NaN      NaN
# 3938951  CHENGDU E&A WAREHOUSE  91316330.0      Z34
# 3938952  Applied Materials Inc      8424.0      099
# 3938953                    NaN         NaN      NaN
#
#         PBI Transaction Description         Type Business Unit  \
# 3938949                         NaN          NaN           NaN
# 3938950                         NaN          NaN           NaN
# 3938951                         SAP  RA Bookings           SEN
# ...

# %%
df1['IGUAL'].value_counts()
# Out:
# GPOS                      204873
# Claims                    140908
# Billings                  101223
# Contracts                   9537
# Transaction Adjustment      5461
# Source                         1
# Name: 2, dtype: int64

# %%
df2 = df1.loc[df1['IGUAL'] == 'TRUE' ]

# %%
df2.head()

# %%
df2.tail()

# %%
s = (df2.loc[df2['Source Transaction ID'] == 'C12224980', "L3 Emp Crediting Hierarchy"])
print(s)
